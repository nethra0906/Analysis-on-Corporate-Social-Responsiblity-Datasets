# %% [markdown]
# EDA ON CSR DATASETS
# -

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LinearRegression

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping C:\Users\intern.ai7\AppData\Local\anaconda3\Lib\site-packages\conda-24.11.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\intern.ai7\AppData\Local\anaconda3\Lib\site-packages\conda-24.11.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\intern.ai7\AppData\Local\anaconda3\Lib\site-packages\conda-24.11.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\intern.ai7\AppData\Local\anaconda3\Lib\site-packages\conda-24.11.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\intern.ai7\AppData\Local\anaconda3\Lib\site-packages\conda-24.11.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\intern.ai7\AppData\Local\anaconda3\Lib\site-packages\conda-24.11.3.dist-info due to invalid metadata entry 'name'

# %% [markdown]
# GOING THROUGH EACH SHEET OF DATA
# -

# %%
import pandas as pd

excel_file = pd.ExcelFile('Data Sheet Compile final.xlsx', engine='openpyxl')

# Display sheet names
print(excel_file.sheet_names)

# Load a specific sheet into a DataFrame
df_sheet1 = pd.read_excel(excel_file, sheet_name='Demography')
df_sheet2 = pd.read_excel(excel_file, sheet_name='Benefits Govt Scheme')
df_sheet3 = pd.read_excel(excel_file, sheet_name='Housing and Facilities')
df_sheet4 = pd.read_excel(excel_file, sheet_name='Occupation and Crop Pattern')
df_sheet5 = pd.read_excel(excel_file, sheet_name='Irrigation')
df_sheet6 = pd.read_excel(excel_file, sheet_name='Agri Annual Income')
df_sheet7 = pd.read_excel(excel_file, sheet_name='Other income and Migration')
df_sheet8 = pd.read_excel(excel_file, sheet_name='Drinking water Status')
df_sheet9 = pd.read_excel(excel_file, sheet_name='health status & expenses')
df_sheet10 = pd.read_excel(excel_file, sheet_name='Education & Expenses')
df_sheet11 = pd.read_excel(excel_file, sheet_name='Need Assessment')

# Display the first few rows of each sheet
print(df_sheet1.head())
print(df_sheet2.head())
print(df_sheet3.head())
print(df_sheet4.head())
print(df_sheet5.head())
print(df_sheet6.head())
print(df_sheet7.head())
print(df_sheet8.head())
print(df_sheet9.head())
print(df_sheet10.head())
print(df_sheet11.head())
# Out:
# ['Demography', 'Benefits Govt Scheme', 'Housing and Facilities', 'Occupation and Crop Pattern', 'Irrigation', 'Agri Annual Income', 'Other income and Migration', 'Drinking water Status', 'health status & expenses', 'Education & Expenses', 'Need Assessment']
#                  Category Subcategory  MAnihari  Barhawadand  Chhadna  Deora  \
# 0  Gender wise Population        Male       749          336      179    502
# 1  Gender wise Population      Female       644          287      181    464
# 2        Age Distribution        0-14       124           98      108    160
# 3        Age Distribution       15-59       981          502      222    695
# 4        Age Distribution         60+       288           23       30    111
#
#    Kolhua  Kukraon  Kunda  Majhauli  Pachaur   Talwa  Tingudi  Ujjaini  \
# 0     292      502    162       684       813    402      503      983
# 1     259      449    153       466       709    398      478      891
# ...

# %% [markdown]
# DESCRIBING EACH SHEET OF DATA
# -

# %%
# Display summary statistics

print(df_sheet1.describe())
print(df_sheet2.describe())
print(df_sheet3.describe())
print(df_sheet4.describe())
print(df_sheet5.describe())
print(df_sheet6.describe())
print(df_sheet7.describe())
print(df_sheet8.describe())
print(df_sheet9.describe())
print(df_sheet10.describe())
print(df_sheet11.describe())
# Out:
#          MAnihari  Barhawadand     Chhadna       Deora      Kolhua  \
# count   22.000000    22.000000   22.000000   22.000000   22.000000
# mean   206.181818    90.954545   50.454545  140.090909  103.045455
# std    268.360922   129.075274   65.340666  183.441676  118.466582
# min      0.000000     0.000000    0.000000    0.000000    0.000000
# 25%     12.500000     5.000000    8.250000   23.000000   10.000000
# 50%    108.500000    40.000000   17.000000   77.000000   55.500000
# 75%    276.000000   114.500000   58.000000  156.500000  163.250000
# max    981.000000   502.000000  222.000000  695.000000  424.000000
#
#           Kukraon       Kunda    Majhauli    Pachaur        Talwa     Tingudi  \
# count   22.000000   22.000000   22.000000   22.000000   22.000000   22.000000
# mean   143.272727   44.545455  214.772727  218.818182  127.500000  151.681818
# std    187.719695   60.094154  215.713198  271.215366  151.248377  191.519087
# ...

# %% [markdown]
# CHECKING FOR NULL VALUES
# -

# %%
print(df.isnull().sum())
# Out:
# Category           0
# Subcategory        0
# MAnihari           0
# Barhawadand        0
# Chhadna            0
# Deora              0
# Kolhua             0
# Kukraon            0
# Kunda              0
# Majhauli           0
# Pachaur            0
# Talwa              0
# Tingudi            0
# Ujjaini            0
# total Frequency    0
# Percentage %       0
# dtype: int64

# %% [markdown]
# HISTOGRAM & BOX PLOT
# -

# %%
df.hist(figsize=(10, 10))
plt.show()

df.plot(kind='box', subplots=True, layout=(4,4), figsize=(12,12))
plt.show()

# %% [markdown]
# COUNT PLOT OF EACH CATEGORY IN DEMOGRAPHY
# -

# %%
for column in df.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(15,10))
    sns.countplot(x=column, data=df)
    plt.show()

# %% [markdown]
# PAIRPLOT OF DEMOGRAPHY
# -

# %%
sns.pairplot(df_sheet1)
plt.show()

# %% [markdown]
# PAIRPLOT OF IRRIGIATION
# -

# %%
sns.pairplot(df_sheet5)
plt.show()

# %% [markdown]
# PAIRPLOT OF AGRICULTURAL INCOME
# -

# %%
sns.pairplot(df_sheet3)
plt.show()
